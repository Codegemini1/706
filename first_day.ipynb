# %%
10 + 8
# Out:
# 18

# %% [markdown]
# # Heading

# %% [markdown]
# Article:- Today is our first class of python

# %% [raw]
# Raw work
# x--- > 83y
# y ---. 835
# xyz ---> 834hfj

# %% [markdown]
# # First Day
